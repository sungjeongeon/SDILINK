# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import numpy as np
from scipy.io import loadmat
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 1. 데이터 전처리

# %% [markdown]
# ## Matlab 파일들 csv파일로 변환

# %%
def load_data(nm,battery): # Example of input load_data('B0006.mat','B0006')
    mat = loadmat(nm)
    print('Total data in cycles: ', len(mat[battery][0, 0]['cycle'][0]))
    counter = 0
    charge_data = []
    discharge_data = []
    capacity_data = []
    
    for i in range(len(mat[battery][0, 0]['cycle'][0])):
        row = mat[battery][0, 0]['cycle'][0, i]
        if row['type'][0] == 'charge':
            ambient_temperature = row['ambient_temperature'][0][0]
            date_time = datetime.datetime(int(row['time'][0][0]),
                                          int(row['time'][0][1]),
                                          int(row['time'][0][2]),
                                          int(row['time'][0][3]),
                                          int(row['time'][0][4])) + datetime.timedelta(seconds=int(row['time'][0][5]))
            data = row['data']
            for j in range(len(data[0][0]['Voltage_measured'][0])):
                voltage_measured = data[0][0]['Voltage_measured'][0][j]
                current_measured = data[0][0]['Current_measured'][0][j]
                temperature_measured = data[0][0]['Temperature_measured'][0][j]
                time = data[0][0]['Time'][0][j]
                charge_data.append([counter + 1, ambient_temperature, date_time,
                                voltage_measured, current_measured,
                                temperature_measured, time])
            counter = counter + 1
    
    print(charge_data[0])
    
    for i in range(len(mat[battery][0, 0]['cycle'][0])):
        row = mat[battery][0, 0]['cycle'][0, i]
        if row['type'][0] == 'discharge':
            ambient_temperature = row['ambient_temperature'][0][0]
            date_time = datetime.datetime(int(row['time'][0][0]),
                                          int(row['time'][0][1]),
                                          int(row['time'][0][2]),
                                          int(row['time'][0][3]),
                                          int(row['time'][0][4])) + datetime.timedelta(seconds=int(row['time'][0][5]))
            data = row['data']
            capacity = data[0][0]['Capacity'][0][0]
            for j in range(len(data[0][0]['Voltage_measured'][0])):
                voltage_measured = data[0][0]['Voltage_measured'][0][j]
                current_measured = data[0][0]['Current_measured'][0][j]
                temperature_measured = data[0][0]['Temperature_measured'][0][j]
                time = data[0][0]['Time'][0][j]
                discharge_data.append([counter + 1, ambient_temperature, date_time, capacity,
                                voltage_measured, current_measured,
                                temperature_measured, time])
            capacity_data.append([counter + 1, ambient_temperature, date_time, capacity])
            counter = counter + 1
            
    print(discharge_data[0])
    
    return [pd.DataFrame(data=charge_data,
                         columns=['cycle', 'ambient_temperature', 'datetime',
                                   'voltage_measured','current_measured',
                                  'temperature_measured','time']),
            pd.DataFrame(data=discharge_data,
                         columns=['cycle', 'ambient_temperature', 'datetime',
                                  'capacity', 'voltage_measured',
                                  'current_measured', 'temperature_measured','time']),
            pd.DataFrame(data=capacity_data,
                         columns=['cycle', 'ambient_temperature', 'datetime',
                                  'capacity'])]

# %% [markdown]
# ## charge, discharge 데이터 합치기

# %%
B0005_charge, B0005_discharge, B0005_capacity = load_data('./nasa_mat/B0005.mat','B0005')
B0005_charge['state'] = 1
B0005_discharge['state'] = 2
# Out:
# Total data in cycles:  616
# [1, 24, datetime.datetime(2008, 4, 2, 13, 8, 17), 3.873017221300996, -0.001200660698297908, 24.65535783391511, 0.0]
# [171, 24, datetime.datetime(2008, 4, 2, 15, 25, 41), 1.8564874208181574, 4.191491807505295, -0.004901589207462691, 24.330033885570543, 0.0]

# %% [markdown]
# # 데이터 중에서 5 cycle만 사용

# %%
# csv 파일 저장
# fuel_cells_df.to_csv('B0005_6_7_18.csv', index=False)

# %%
B0005_charge
# Out:
#         cycle  ambient_temperature            datetime  voltage_measured  \
# 0           1                   24 2008-04-02 13:08:17          3.873017
# 1           1                   24 2008-04-02 13:08:17          3.479394
# 2           1                   24 2008-04-02 13:08:17          4.000588
# 3           1                   24 2008-04-02 13:08:17          4.012395
# 4           1                   24 2008-04-02 13:08:17          4.019708
# ...       ...                  ...                 ...               ...
# 541168    170                   24 2008-05-28 11:09:42          0.236356
# 541169    170                   24 2008-05-28 11:09:42          0.003365
# 541170    170                   24 2008-05-28 11:09:42          4.985137
# 541171    170                   24 2008-05-28 11:09:42          4.984720
# 541172    170                   24 2008-05-28 11:09:42          4.213440
#
#         current_measured  temperature_measured    time  state
# 0              -0.001201             24.655358   0.000      1
# 1              -4.030268             24.666480   2.532      1
# 2               1.512731             24.675394   5.500      1
# 3               1.509063             24.693865   8.344      1
# 4               1.511318             24.705069  11.125      1
# ...                  ...                   ...     ...    ...
# 541168         -0.003484             23.372048   0.000      1
# 541169         -0.001496             23.369434   2.547      1
# 541170          0.000506             23.386535   5.500      1
# 541171          0.000442             23.386983   8.312      1
# 541172         -0.000734             23.385061  12.656      1
#
# [541173 rows x 8 columns]

# %%
B0005_discharge
# Out:
#        cycle  ambient_temperature            datetime  capacity  \
# 0        171                   24 2008-04-02 15:25:41  1.856487
# 1        171                   24 2008-04-02 15:25:41  1.856487
# 2        171                   24 2008-04-02 15:25:41  1.856487
# 3        171                   24 2008-04-02 15:25:41  1.856487
# 4        171                   24 2008-04-02 15:25:41  1.856487
# ...      ...                  ...                 ...       ...
# 50280    338                   24 2008-05-27 20:45:42  1.325079
# 50281    338                   24 2008-05-27 20:45:42  1.325079
# 50282    338                   24 2008-05-27 20:45:42  1.325079
# 50283    338                   24 2008-05-27 20:45:42  1.325079
# 50284    338                   24 2008-05-27 20:45:42  1.325079
#
#        voltage_measured  current_measured  temperature_measured      time  \
# 0              4.191492         -0.004902             24.330034     0.000
# 1              4.190749         -0.001478             24.325993    16.781
# 2              3.974871         -2.012528             24.389085    35.703
# 3              3.951717         -2.013979             24.544752    53.781
# 4              3.934352         -2.011144             24.731385    71.922
# ...                 ...               ...                   ...       ...
# 50280          3.579262         -0.001569             34.864823  2781.312
# 50281          3.581964         -0.003067             34.814770  2791.062
# 50282          3.584484         -0.003079             34.676258  2800.828
# 50283          3.587336          0.001219             34.565580  2810.640
# 50284          3.589937         -0.000583             34.405920  2820.390
#
#        state
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2
# ...      ...
# 50280      2
# 50281      2
# 50282      2
# 50283      2
# 50284      2
#
# [50285 rows x 9 columns]

# %%
# Cycle 일치 시키기
B0005_discharge['cycle'] = B0005_discharge['cycle'] - 170

# %%
B0005_discharge
# Out:
#        cycle  ambient_temperature            datetime  capacity  \
# 0          1                   24 2008-04-02 15:25:41  1.856487
# 1          1                   24 2008-04-02 15:25:41  1.856487
# 2          1                   24 2008-04-02 15:25:41  1.856487
# 3          1                   24 2008-04-02 15:25:41  1.856487
# 4          1                   24 2008-04-02 15:25:41  1.856487
# ...      ...                  ...                 ...       ...
# 50280    168                   24 2008-05-27 20:45:42  1.325079
# 50281    168                   24 2008-05-27 20:45:42  1.325079
# 50282    168                   24 2008-05-27 20:45:42  1.325079
# 50283    168                   24 2008-05-27 20:45:42  1.325079
# 50284    168                   24 2008-05-27 20:45:42  1.325079
#
#        voltage_measured  current_measured  temperature_measured      time  \
# 0              4.191492         -0.004902             24.330034     0.000
# 1              4.190749         -0.001478             24.325993    16.781
# 2              3.974871         -2.012528             24.389085    35.703
# 3              3.951717         -2.013979             24.544752    53.781
# 4              3.934352         -2.011144             24.731385    71.922
# ...                 ...               ...                   ...       ...
# 50280          3.579262         -0.001569             34.864823  2781.312
# 50281          3.581964         -0.003067             34.814770  2791.062
# 50282          3.584484         -0.003079             34.676258  2800.828
# 50283          3.587336          0.001219             34.565580  2810.640
# 50284          3.589937         -0.000583             34.405920  2820.390
#
#        state
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2
# ...      ...
# 50280      2
# 50281      2
# 50282      2
# 50283      2
# 50284      2
#
# [50285 rows x 9 columns]

# %%
B0005_capacity
# Out:
#      cycle  ambient_temperature            datetime  capacity
# 0      171                   24 2008-04-02 15:25:41  1.856487
# 1      172                   24 2008-04-02 19:43:48  1.846327
# 2      173                   24 2008-04-03 00:01:06  1.835349
# 3      174                   24 2008-04-03 04:16:37  1.835263
# 4      175                   24 2008-04-03 08:33:25  1.834646
# ..     ...                  ...                 ...       ...
# 163    334                   24 2008-05-26 10:44:38  1.293464
# 164    335                   24 2008-05-26 15:30:43  1.288003
# 165    336                   24 2008-05-26 20:21:04  1.287453
# 166    337                   24 2008-05-27 15:52:41  1.309015
# 167    338                   24 2008-05-27 20:45:42  1.325079
#
# [168 rows x 4 columns]

# %%
# assume B0005_charge and B0005_discharge are two data frames with the same columns
B0005_dataset = pd.concat([B0005_charge, B0005_discharge], axis=0)  # axis=0 means concatenate vertically
B0005_dataset = B0005_dataset.sort_values(by='datetime')  # sort by the datetime column
B0005_dataset = B0005_dataset.reset_index(drop=True)

# %%
B0005_dataset
# Out:
#         cycle  ambient_temperature            datetime  voltage_measured  \
# 0           1                   24 2008-04-02 13:08:17          3.873017
# 1           1                   24 2008-04-02 13:08:17          4.206165
# 2           1                   24 2008-04-02 13:08:17          4.206186
# 3           1                   24 2008-04-02 13:08:17          4.206023
# 4           1                   24 2008-04-02 13:08:17          4.206403
# ...       ...                  ...                 ...               ...
# 591453    170                   24 2008-05-28 11:09:42          0.236356
# 591454    170                   24 2008-05-28 11:09:42          0.003365
# 591455    170                   24 2008-05-28 11:09:42          4.985137
# 591456    170                   24 2008-05-28 11:09:42          4.984720
# 591457    170                   24 2008-05-28 11:09:42          4.213440
#
#         current_measured  temperature_measured      time  state  capacity
# 0              -0.001201             24.655358     0.000      1       NaN
# 1               0.151859             24.540692  3562.985      1       NaN
# 2               0.151080             24.537357  3574.938      1       NaN
# 3               0.148962             24.537892  3587.016      1       NaN
# 4               0.150266             24.531517  3599.125      1       NaN
# ...                  ...                   ...       ...    ...       ...
# 591453         -0.003484             23.372048     0.000      1       NaN
# 591454         -0.001496             23.369434     2.547      1       NaN
# 591455          0.000506             23.386535     5.500      1       NaN
# 591456          0.000442             23.386983     8.312      1       NaN
# 591457         -0.000734             23.385061    12.656      1       NaN
#
# [591458 rows x 9 columns]

# %%
B0005_dataset.describe()
# Out:
#                cycle  ambient_temperature  voltage_measured  current_measured  \
# count  591458.000000             591458.0     591458.000000     591458.000000
# mean       95.885468                 24.0          4.103945          0.369404
# std        43.030452                  0.0          0.213469          0.907558
# min         1.000000                 24.0          0.003365         -4.479660
# 25%        61.000000                 24.0          4.089426          0.040636
# 50%        96.000000                 24.0          4.205140          0.171961
# 75%       133.000000                 24.0          4.205908          1.259778
# max       170.000000                 24.0          8.393141          1.531301
#
#        temperature_measured           time          state      capacity
# count         591458.000000  591458.000000  591458.000000  50285.000000
# mean              26.369701    4763.856934       1.085019      1.560345
# std                2.772424    3147.859026       0.278910      0.182380
# min               23.214802       0.000000       1.000000      1.287453
# 25%               24.488485    1928.175750       1.000000      1.386229
# 50%               25.479630    4467.515500       1.000000      1.538237
# 75%               27.348768    7503.824000       1.000000      1.746871
# max               41.450232   10807.328000       2.000000      1.856487

# %%
categorical_cols = ['state']

# %%
plt.figure(figsize = (7,8))
count = (B0005_dataset['state'].value_counts(normalize=True)*100)
count.plot.pie(colors = sns.color_palette("flare"),autopct='%0.0f%%',
                       textprops={'fontsize': 14},shadow = True)
plt.show()

# %%
plt.figure(figsize=(15, 7))
sns.lineplot(x = 'datetime', y = 'capacity', data = B0005_dataset, palette = ['r','g','b','y'])
plt.show()

# %% [markdown]
# # 2. 데이터 생성

# %% [markdown]
# ## 2-0. 충전 기준 데이터 삭제

# %%
# 충전 기준 데이터 1/10
# State가 1인 데이터 필터링
state_1_df = B0005_dataset[B0005_dataset['state'] == 1]

# 각 Cycle 기준으로 데이터를 1/10로 줄이기
grouped = state_1_df.groupby('cycle')
selected_rows = []
for cycle, group in grouped:
    num_rows_to_select = int(len(group) / 10)
    selected_rows.extend(group.head(num_rows_to_select).index.tolist())

# 선택된 행만 포함하는 새 데이터프레임 생성
reduced_state_1_df = state_1_df.loc[selected_rows]

# State가 2인 데이터 필터링
state_2_df = B0005_dataset[B0005_dataset['state'] == 2]

# 두 데이터프레임 합치기
B0005_dataset = pd.concat([reduced_state_1_df, state_2_df])

# 인덱스 재정렬
B0005_dataset.reset_index(drop=True, inplace=True)

# %%
B0005_dataset
# Out:
#         cycle  ambient_temperature            datetime  voltage_measured  \
# 0           1                   24 2008-04-02 13:08:17          3.873017
# 1           1                   24 2008-04-02 13:08:17          4.206165
# 2           1                   24 2008-04-02 13:08:17          4.206186
# 3           1                   24 2008-04-02 13:08:17          4.206023
# 4           1                   24 2008-04-02 13:08:17          4.206403
# ...       ...                  ...                 ...               ...
# 104329    168                   24 2008-05-27 20:45:42          3.548236
# 104330    168                   24 2008-05-27 20:45:42          3.551060
# 104331    168                   24 2008-05-27 20:45:42          3.553517
# 104332    168                   24 2008-05-27 20:45:42          3.535001
# 104333    168                   24 2008-05-27 20:45:42          3.589937
#
#         current_measured  temperature_measured      time  state  capacity
# 0              -0.001201             24.655358     0.000      1       NaN
# 1               0.151859             24.540692  3562.985      1       NaN
# 2               0.151080             24.537357  3574.938      1       NaN
# 3               0.148962             24.537892  3587.016      1       NaN
# 4               0.150266             24.531517  3599.125      1       NaN
# ...                  ...                   ...       ...    ...       ...
# 104329         -2.015007             31.623496   890.781      2  1.325079
# 104330         -2.003196             31.584361   881.421      2  1.325079
# 104331         -2.008633             31.571732   872.046      2  1.325079
# 104332         -2.014372             31.886947   937.671      2  1.325079
# 104333         -0.000583             34.405920  2820.390      2  1.325079
#
# [104334 rows x 9 columns]

# %%
# 데이터 중에서 5개만 사용
B0005_dataset = B0005_dataset[(B0005_dataset['cycle'] >= 1) & (B0005_dataset['cycle'] <= 50)]

# %% [markdown]
# ### 추가 데이터(SoH, Soc) 생성

# %%
# 데이터 SoH(현재 수용량 / 최초 수용량)
C = 1.856487

# %%
for i in range(len(B0005_dataset)):
    B0005_dataset['SoH']=(B0005_dataset['capacity'])/C

# %%
B0005_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104334 entries, 0 to 104333
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   cycle                 104334 non-null  int64
#  1   ambient_temperature   104334 non-null  uint8
#  2   datetime              104334 non-null  datetime64[ns]
#  3   voltage_measured      104334 non-null  float64
#  4   current_measured      104334 non-null  float64
#  5   temperature_measured  104334 non-null  float64
#  6   time                  104334 non-null  float64
#  7   state                 104334 non-null  int64
#  8   capacity              50285 non-null   float64
#  9   SoH                   50285 non-null   float64
# dtypes: datetime64[ns](1), float64(6), int64(2), uint8(1)
# memory usage: 7.3 MB

# %%
B0005_dataset
# Out:
#         cycle  ambient_temperature            datetime  voltage_measured  \
# 0           1                   24 2008-04-02 13:08:17          3.873017
# 1           1                   24 2008-04-02 13:08:17          4.206165
# 2           1                   24 2008-04-02 13:08:17          4.206186
# 3           1                   24 2008-04-02 13:08:17          4.206023
# 4           1                   24 2008-04-02 13:08:17          4.206403
# ...       ...                  ...                 ...               ...
# 104329    168                   24 2008-05-27 20:45:42          3.548236
# 104330    168                   24 2008-05-27 20:45:42          3.551060
# 104331    168                   24 2008-05-27 20:45:42          3.553517
# 104332    168                   24 2008-05-27 20:45:42          3.535001
# 104333    168                   24 2008-05-27 20:45:42          3.589937
#
#         current_measured  temperature_measured      time  state  capacity  \
# 0              -0.001201             24.655358     0.000      1       NaN
# 1               0.151859             24.540692  3562.985      1       NaN
# 2               0.151080             24.537357  3574.938      1       NaN
# 3               0.148962             24.537892  3587.016      1       NaN
# 4               0.150266             24.531517  3599.125      1       NaN
# ...                  ...                   ...       ...    ...       ...
# 104329         -2.015007             31.623496   890.781      2  1.325079
# 104330         -2.003196             31.584361   881.421      2  1.325079
# 104331         -2.008633             31.571732   872.046      2  1.325079
# 104332         -2.014372             31.886947   937.671      2  1.325079
# 104333         -0.000583             34.405920  2820.390      2  1.325079
#
#              SoH
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 104329  0.713756
# 104330  0.713756
# 104331  0.713756
# 104332  0.713756
# 104333  0.713756
#
# [104334 rows x 10 columns]

# %%
# Create a new column 'SoC' with default value None
B0005_dataset['SoC'] = None

# %%
# Function to set SoC values based on conditions
def set_soc_values(df, cycle, state):
    cycle_df = df[(df['cycle'] == cycle) & (df['state'] == state)]
    num_rows = len(cycle_df)

    if state == 1:
        start_value, end_value = 0, 100
    elif state == 2:
        start_value, end_value = 100, 0
    else:
        return

    soc_values = [round(x, 2) for x in np.linspace(start_value, end_value, num_rows)]
    df.loc[cycle_df.index, 'SoC'] = soc_values

# %%
# Set SoC values for cycles 1 to 5 and states 1 and 2
for cycle in range(1, 6):
    for state in [1, 2]:
        set_soc_values(B0005_dataset, cycle, state)

# %%
B0005_dataset
# Out:
#         cycle  ambient_temperature            datetime  voltage_measured  \
# 0           1                   24 2008-04-02 13:08:17          3.873017
# 1           1                   24 2008-04-02 13:08:17          4.206165
# 2           1                   24 2008-04-02 13:08:17          4.206186
# 3           1                   24 2008-04-02 13:08:17          4.206023
# 4           1                   24 2008-04-02 13:08:17          4.206403
# ...       ...                  ...                 ...               ...
# 104329    168                   24 2008-05-27 20:45:42          3.548236
# 104330    168                   24 2008-05-27 20:45:42          3.551060
# 104331    168                   24 2008-05-27 20:45:42          3.553517
# 104332    168                   24 2008-05-27 20:45:42          3.535001
# 104333    168                   24 2008-05-27 20:45:42          3.589937
#
#         current_measured  temperature_measured      time  state  capacity  \
# 0              -0.001201             24.655358     0.000      1       NaN
# 1               0.151859             24.540692  3562.985      1       NaN
# 2               0.151080             24.537357  3574.938      1       NaN
# 3               0.148962             24.537892  3587.016      1       NaN
# 4               0.150266             24.531517  3599.125      1       NaN
# ...                  ...                   ...       ...    ...       ...
# 104329         -2.015007             31.623496   890.781      2  1.325079
# 104330         -2.003196             31.584361   881.421      2  1.325079
# 104331         -2.008633             31.571732   872.046      2  1.325079
# 104332         -2.014372             31.886947   937.671      2  1.325079
# 104333         -0.000583             34.405920  2820.390      2  1.325079
#
#              SoH   SoC
# 0            NaN   0.0
# 1            NaN   1.3
# 2            NaN   2.6
# 3            NaN   3.9
# 4            NaN  5.19
# ...          ...   ...
# 104329  0.713756  None
# 104330  0.713756  None
# 104331  0.713756  None
# 104332  0.713756  None
# 104333  0.713756  None
#
# [104334 rows x 11 columns]

# %% [markdown]
# ## 2-1. 데이터 스케일링

# %%
def scale_column(column, average, min_value, max_value):
    scaled_column = (column - column.min()) / (column.max() - column.min()) * (max_value - min_value) + min_value
    scaled_column[scaled_column < min_value] = min_value
    scaled_column[scaled_column > max_value] = max_value
    return scaled_column

B0005_dataset['voltage_measured'] = scale_column(B0005_dataset['voltage_measured'], 377, 350, 390)
B0005_dataset['current_measured'] = scale_column(B0005_dataset['current_measured'], 100, 0, 200)
B0005_dataset['temperature_measured'] = scale_column(B0005_dataset['temperature_measured'], 25, 15, 40)

# %%
B0005_dataset
# Out:
#         cycle  ambient_temperature            datetime  voltage_measured  \
# 0           1                   24 2008-04-02 13:08:17        382.080245
# 1           1                   24 2008-04-02 13:08:17        389.620754
# 2           1                   24 2008-04-02 13:08:17        389.621229
# 3           1                   24 2008-04-02 13:08:17        389.617545
# 4           1                   24 2008-04-02 13:08:17        389.626160
# ...       ...                  ...                 ...               ...
# 104329    168                   24 2008-05-27 20:45:42        374.729090
# 104330    168                   24 2008-05-27 20:45:42        374.793012
# 104331    168                   24 2008-05-27 20:45:42        374.848633
# 104332    168                   24 2008-05-27 20:45:42        374.429529
# 104333    168                   24 2008-05-27 20:45:42        375.672972
#
#         current_measured  temperature_measured      time  state  capacity  \
# 0             142.740135             16.974941     0.000      1       NaN
# 1             148.501928             16.817740  3562.985      1       NaN
# 2             148.472582             16.813167  3574.938      1       NaN
# 3             148.392854             16.813901  3587.016      1       NaN
# 4             148.441930             16.805161  3599.125      1       NaN
# ...                  ...                   ...       ...    ...       ...
# 104329         66.932381             26.527963   890.781      2  1.325079
# 104330         67.376966             26.474310   881.421      2  1.325079
# 104331         67.172329             26.456997   872.046      2  1.325079
# 104332         66.956258             26.889142   937.671      2  1.325079
# 104333        142.763373             30.342548  2820.390      2  1.325079
#
#              SoH   SoC
# 0            NaN   0.0
# 1            NaN   1.3
# 2            NaN   2.6
# 3            NaN   3.9
# 4            NaN  5.19
# ...          ...   ...
# 104329  0.713756  None
# 104330  0.713756  None
# 104331  0.713756  None
# 104332  0.713756  None
# 104333  0.713756  None
#
# [104334 rows x 11 columns]

# %%
B0005_dataset.dtypes
# Out:
# cycle                            int64
# ambient_temperature              uint8
# datetime                datetime64[ns]
# voltage_measured               float64
# current_measured               float64
# temperature_measured           float64
# time                           float64
# state                            int64
# capacity                       float64
# SoH                            float64
# SoC                             object
# dtype: object

# %%
# Remove duplicate values from the 'datetime' column and keep the first occurrence
B0005_datetime = B0005_dataset.drop_duplicates(subset=['datetime'], keep='first')

# Reset the index of the DataFrame, if needed
B0005_datetime = B0005_datetime.reset_index(drop=True)

# %% [markdown]
# ## 2-2. 데이터 날짜 재배열

# %%
import numpy as np
from datetime import datetime, timedelta

# %%
# 날짜 범위 설정
start_date = datetime(2023, 1, 1, 0, 0, 0)
end_date = datetime(2023, 5, 18, 0, 0, 0)

# %%
# 랜덤 날짜 생성 함수
def random_date(start, end):
    delta = end - start
    int_delta = (delta.days * 24 * 60 * 60) + delta.seconds
    random_second = np.random.randint(0, int_delta)
    return start + timedelta(seconds=random_second)

# %%
# 조건에 따른 날짜 할당
previous_cycle = None
previous_state = None
previous_date = None

# %%
dates = []

# %%
for index, row in B0005_dataset.iterrows():
    if row['cycle'] == previous_cycle and row['state'] == previous_state:
        new_date = previous_date + timedelta(minutes=1)
    else:
        new_date = random_date(start_date, end_date)
        while previous_date is not None and new_date < previous_date:
            new_date = random_date(start_date, end_date)
    
    dates.append(new_date)
    previous_cycle = row['cycle']
    previous_state = row['state']
    previous_date = new_date
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[52], line 7
#       5     new_date = random_date(start_date, end_date)
#       6     while previous_date is not None and new_date < previous_date:
# ----> 7         new_date = random_date(start_date, end_date)
#       9 dates.append(new_date)
#      10 previous_cycle = row['cycle']
#
# KeyboardInterrupt:

# %%
B0005_dataset['datetime'] = dates

# %%
B0005_dataset

# %% [markdown]
# - 충전 : 4월 12, 19, 25일 / 5월 3, 9일
# - 방전 : 4월 17, 24 / 5월 1, 8, 16일

# %%
from datetime import datetime, timedelta

# %%
B0005_datetime
# Out:
#      cycle  ambient_temperature            datetime  voltage_measured  \
# 0        1                   24 2008-04-02 13:08:17        382.080245
# 1        2                   24 2008-04-02 16:37:51        383.020661
# 2        3                   24 2008-04-02 20:55:40        389.614264
# 3        4                   24 2008-04-03 01:12:38        389.609653
# 4        5                   24 2008-04-03 05:27:49        389.628785
# ..     ...                  ...                 ...               ...
# 332    164                   24 2008-05-26 10:44:38        369.017450
# 333    165                   24 2008-05-26 15:30:43        370.830658
# 334    166                   24 2008-05-26 20:21:04        368.938143
# 335    167                   24 2008-05-27 15:52:41        369.534817
# 336    168                   24 2008-05-27 20:45:42        370.066791
#
#      current_measured  temperature_measured      time  state  capacity  \
# 0          142.740135             16.974941     0.000      1       NaN
# 1          199.671226             19.693675   703.797      1       NaN
# 2          144.053712             17.018163  9020.391      1       NaN
# 3          144.949520             17.087572  7901.250      1       NaN
# 4          144.010512             16.695771  9369.828      1       NaN
# ..                ...                   ...       ...    ...       ...
# 332         66.974409             33.207224  1846.093      2  1.293464
# 333         66.915146             30.671626  1537.469      2  1.288003
# 334         66.956267             33.401941  1845.719      2  1.287453
# 335        142.746624             38.709465  2423.141      2  1.309015
# 336         66.981620             32.846029  1799.515      2  1.325079
#
#           SoH   SoC
# 0         NaN   0.0
# 1         NaN   0.0
# 2         NaN   0.0
# 3         NaN   0.0
# 4         NaN   0.0
# ..        ...   ...
# 332  0.696726  None
# 333  0.693785  None
# 334  0.693489  None
# 335  0.705103  None
# 336  0.713756  None
#
# [337 rows x 11 columns]

# %%
# State 값이 1인 데이터의 시작 Datetime
state_1_start_dates = [
    '2023-04-12 19:00:00',
    '2023-04-19 19:00:00',
    '2023-04-25 19:00:00',
    '2023-05-03 19:00:00',
    '2023-05-09 19:00:00'
]

# State 값이 2인 데이터의 시작 Datetime
state_2_start_dates = [
    '2023-04-17 19:00:00',
    '2023-04-24 19:00:00',
    '2023-05-01 19:00:00',
    '2023-05-08 19:00:00',
    '2023-05-12 19:00:00'
]

# %%
def update_datetime(row):
    cycle = row['cycle']
    state = row['state']
    start_date = datetime.strptime(state_1_start_dates[cycle - 1], '%Y-%m-%d %H:%M:%S') if state == 1 else datetime.strptime(state_2_start_dates[cycle - 1], '%Y-%m-%d %H:%M:%S')
    minutes_offset = timedelta(minutes=row.name)
    updated_datetime = start_date + minutes_offset
    return updated_datetime.strftime('%Y-%m-%d %H:%M:%S')

# %%
B0005_dataset['datetime'] = B0005_dataset.apply(update_datetime, axis=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 B0005_dataset['datetime'] = B0005_dataset.apply(update_datetime, axis=1)
#
# File ~\anaconda3\envs\b4u\lib\site-packages\pandas\core\frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\envs\b4u\lib\site-packages\pandas\core\apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# File ~\anaconda3\envs\b4u\lib\site-packages\pandas\core\apply.py:891, in FrameApply.apply_standard(self)
#     890 def apply_standard(self):
# --> 891     results, res_index = self.apply_series_generator()
#     893     # wrap results
#     894     return self.wrap_results(results, res_index)
#
# File ~\anaconda3\envs\b4u\lib\site-packages\pandas\core\apply.py:907, in FrameApply.apply_series_generator(self)
#     904 with option_context("mode.chained_assignment", None):
#     905     for i, v in enumerate(series_gen):
#     906         # ignore SettingWithCopy here in case the user mutates
# --> 907         results[i] = self.f(v)
#     908         if isinstance(results[i], ABCSeries):
#     909             # If we have a view on v, we need to make a copy because
#     910             #  series_generator will swap out the underlying data
#     911             results[i] = results[i].copy(deep=False)
#
# Cell In[33], line 4, in update_datetime(row)
#       2 cycle = row['cycle']
#       3 state = row['state']
# ----> 4 start_date = datetime.strptime(state_1_start_dates[cycle - 1], '%Y-%m-%d %H:%M:%S') if state == 1 else datetime.strptime(state_2_start_dates[cycle - 1], '%Y-%m-%d %H:%M:%S')
#       5 minutes_offset = timedelta(minutes=row.name)
#       6 updated_datetime = start_date + minutes_offset
#
# IndexError: list index out of range

# %%
B0005_dataset

# %% [markdown]
# ## 배터리 일련 번호 생성

# %% [markdown]
# ### 배터리 셀 일련번호

# %%
extended_B0005_dataset = B0005_dataset.loc[B0005_dataset.index.repeat(96)].reset_index(drop=True)
BSN_c_values = ['SN-C' + str(i).zfill(5) for i in range(10001, 10097)]
extended_B0005_dataset['BSN-c'] = BSN_c_values * len(B0005_dataset)

# %%
extended_B0005_dataset

# %% [markdown]
# ### 배터리 모듈 일련번호

# %%
BSN_m_values = ['SN-M' + str(i).zfill(5) for i in range(10001, 10009)]

def assign_BSN_m(BSN_c_value):
    BSN_c_number = int(BSN_c_value.split('-C')[-1])
    BSN_m_index = (BSN_c_number - 10001) // 12
    return BSN_m_values[BSN_m_index]

extended_B0005_dataset['BSN-m'] = extended_B0005_dataset['BSN-c'].apply(assign_BSN_m)

# %%
extended_B0005_dataset

# %% [markdown]
# ### 배터리 팩 일련번호

# %%
extended_B0005_dataset['BSN-p'] = 'SN-P10001'

# %%
extended_B0005_dataset

# %%
bsn_B0005_dataset = extended_B0005_dataset

# %%
bsn_B0005_dataset

# %% [markdown]
# ## 배터리 전압 데이터 분리

# %% [markdown]
# ### 배터리 모듈 전압 데이터

# %%
import random

# %%
def generate_random_number_3():
    return round(random.uniform(-3, 3), 2)

# %%
random_values = {BSN_m: generate_random_number_3() for BSN_m in BSN_m_values}

# %%
def calculate_voltage_measured_module(row):
    voltage_measured = row['voltage_measured']
    BSN_m = row['BSN-m']
    random_value = random_values[BSN_m]
    return voltage_measured / 8 + random_value

# %%
bsn_B0005_dataset['voltage_measured_module'] = bsn_B0005_dataset.apply(calculate_voltage_measured_module, axis=1)

# %%
bsn_B0005_dataset

# %% [markdown]
# ### 배터리 셀 전압 데이터

# %%
def generate_random_number_1():
    return round(random.uniform(-1, 1), 2)

# %%
random_values = {BSN_c: generate_random_number_1() for BSN_c in BSN_c_values}

# %%
def calculate_voltage_measured_cell(row):
    voltage_measured_module = row['voltage_measured_module']
    BSN_c = row['BSN-c']
    random_value = random_values[BSN_c]
    return voltage_measured_module / 12 + random_value

# %%
bsn_B0005_dataset['voltage_measured_cell'] = bsn_B0005_dataset.apply(calculate_voltage_measured_cell, axis=1)

# %%
bsn_B0005_dataset

# %% [markdown]
# ### 배터리 모듈 온도 데이터

# %%
random_values = {BSN_m: generate_random_number_3() for BSN_m in BSN_m_values}

# %%
def calculate_temperature_measured_module(row):
    temperature_measured = row['temperature_measured']
    BSN_m = row['BSN-m']
    random_value = random_values[BSN_m]
    return temperature_measured + random_value

# %%
bsn_B0005_dataset['temperature_measured_module'] = bsn_B0005_dataset.apply(calculate_temperature_measured_module, axis=1)

# %%
bsn_B0005_dataset

# %%
bsn_B0005_dataset

# %%
final_dataset = pd.DataFrame()

# %%
final_dataset['BSM-p'] = bsn_B0005_dataset['BSN-p']
final_dataset['BSM-m'] = bsn_B0005_dataset['BSN-m']
final_dataset['BSM-c'] = bsn_B0005_dataset['BSN-c']
final_dataset['Datetime'] = bsn_B0005_dataset['datetime']
final_dataset['Voltage-p'] = bsn_B0005_dataset['voltage_measured']
final_dataset['Voltage-m'] = bsn_B0005_dataset['voltage_measured_module']
final_dataset['Voltage-c'] = bsn_B0005_dataset['voltage_measured_cell']
final_dataset['Current'] = bsn_B0005_dataset['current_measured']
final_dataset['Temperature-p'] = bsn_B0005_dataset['temperature_measured']
final_dataset['Temperature-m'] = bsn_B0005_dataset['temperature_measured_module']
final_dataset['State'] = bsn_B0005_dataset['state']
final_dataset['Capacity'] = bsn_B0005_dataset['capacity']
final_dataset['SOC'] = bsn_B0005_dataset['SoC']
final_dataset['SOH'] = bsn_B0005_dataset['SoH']
final_dataset['Cycles'] = bsn_B0005_dataset['cycle']

# %%
cycles_5_final_dataset = final_dataset

# %%
cycles_5_final_dataset

# %%
cycles_5_final_dataset

# %%
# csv 파일 저장
cycles_5_final_dataset.to_csv('cycles_5_final_dataset.csv', index=False)
